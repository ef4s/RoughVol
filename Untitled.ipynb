# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
from statsmodels.graphics.tsaplots import *
# %matplotlib inline

import numpy as np
import pandas as pd


import fbm

# %% [markdown]
# # Volatility Is Rough

# %% [markdown]
# ## Fractional Brownian Motion

# %% [markdown]
# Fractional Brownian Motion (fBM) is like Brownian Motion, but the increments are not necessarily independent. For our purposes, the most important result is that the sign of the autocorrelation is determined by the Hurst exponent:
# * $H<0.5$ increments are *positively* correlated
# * $H=0.5$ increments are independent
# * $H>0.5$ increments are *negatively* correlated

# %% [markdown]
# [Man Group Data](http://realized.oxford-man.ox.ac.uk/data/download)

# %%
man = pd.read_csv('OxfordManRealizedVolatilityIndices.csv', header=2, index_col=0, parse_dates=True, usecols=[0,1])
man = np.log(man['SPX2.rv'].
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-c96df2fca209> in <module>()
#       1 man = pd.read_csv('OxfordManRealizedVolatilityIndices.csv', header=2, index_col=0, parse_dates=True, usecols=[0,1])
# ----> 2 man = np.log(man['SPX2.rv'].sqrt())
#
# C:\Users\peter\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'sqrt'

# %%
fig = plt.figure(figsize=(8, 6))
fig.suptitle('MAN Group S&P 500 5 minute realised variance', fontsize=14, fontweight='bold')

ax = fig.add_subplot(111)
man.plot(ax=ax)

ax.set_ylabel('Log Realised Variance')
ax.xaxis.label.set_visible(False)

# %%
fig = plt.figure(figsize=(8, 12))
fig.suptitle('MAN Group S&P 500 5 minute realised variance', fontsize=14, fontweight='bold')

ax = fig.add_subplot(211)
plot_pacf(man.dropna(), lags=list(range(50)), ax=ax)
ax.set_title('Partial Autocorrelation of Variance')

ax2 = fig.add_subplot(212)
plot_acf(man.diff().dropna(), lags=list(range(50)), ax=ax2)
ax2.set_title('Autocorrelation of Difference')

ax.set_ylabel('Log Realised Variance')
ax2.set_ylabel('Log Realised Variance')
ax2.set_xlabel('Lags')

# %% [markdown]
# $m(q, \Delta)=\frac{1}{N}\sum_{k=1}^N |{\log(\sigma_{k\Delta}) - \log(\sigma_{(k-1)\Delta})}|^q$
#
# Which in python becomes:
# ```python
# m = sigma.log().diff(periods=k).abs().pow(q).mean()
# ```

# %%
q_s = np.arange(0.5, 3.5, 0.5)
idx = list(range(1, 100))
res = []
for q in q_s:
    _res = []
    for k in idx:
        _res.append(man.diff(periods=k).abs().pow(q).mean())
    res.append(pd.Series(_res, index=idx))
res = pd.DataFrame(res, index=q_s).T

# %%
fig = plt.figure()
fig.suptitle('MAN Group S&P 500 5 minute realised variance', fontsize=14, fontweight='bold')

ax = fig.add_subplot(111)

res.plot(logx=True, logy=True, style='.', colormap='viridis', ax=ax)


# ax.xaxis.set_major_formatter(ScalarFormatter())
# ax.yaxis.set_major_formatter(ScalarFormatter())

# %%
np.exp(4)
# Out:
# 54.598150033144236

# %%
fig = plt.figure()
fig.suptitle('MAN group S&P 500 5 minute realised variance', fontsize=14, fontweight='bold')

ax = fig.add_subplot(111)
man.diff().plot.hist(bins=300, ax=ax)

ax.set_ylabel('Realised Variance')
ax.xaxis.label.set_visible(False)
# ax.set_xlim(0.0005, -0.0005)

# %% [markdown]
# $$\log\sigma_{t+\Delta} - \log\sigma_{t}=v(W_{t+\Delta}^H - W_{t}^H)$$

# %%
n = 100
exponents = [0.1, 0.25, 0.5, 0.75]
for hurst in [0.1, 0.25, 0.5, 0.75]:
    fbmr, _, times = fbm.fbm(n, H=hurst, L=1, method='daviesharte', random_seed=1337)
    plt.plot(times, fbmr)
plt.legend(exponents)
